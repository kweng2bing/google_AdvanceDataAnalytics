# %% [markdown]
# ## Q-Q Plot (Quantile-Quantile Plot)

# %% [markdown]
# ## Purpose
#
# * A graphical method to determine whether a dataset follows a specific probability distribution by plotting their quantiles against each other
#
#
# ### Quantiles
# * Points in a dataset that divide the data into intervals containing equal probabilities/proportions of the total distributions.
# * Used to describe the spread of data set
#
# #### Examples of Quantiles
# * Median
# * Quartiles
# * Percentiles

# %% [markdown]
# ## Procedure
#
# 1. Sort the residuals in ascending order
# 2. Compare to a normal distribution
#
#
#
#
# Self Note: Q-Q Plot tests if the data follows normal distribution via inverse cdf method.
# 1. $X \rightarrow [0,1]$ via position plotting function (Rank Probability Formulas)
# 2. $[0,1] \rightarrow [-\infty, \infty]= \hat{X}$ Inverse CDF Method
# 3. $X \sim \hat{X}$ Plot quantile values of $N(0,1)$ (x-axis) and rank-ordered residuals on its (y-axis)
#
#
# ### Questions
#
# 1. Why does this work?
#     * Since data is sorted via increasing order, we have

# %%
# Simplified code for Q-Q plot

import statsmodels.api as sm
import matplotlib.pyplot as plt

residuals = model.resid
fig = sm.qqplot(residuals, line = 's')
plt.show()

# %% [markdown]
# ### Resources
#
# * https://www.geeksforgeeks.org/data-analysis/quantile-quantile-plots/
